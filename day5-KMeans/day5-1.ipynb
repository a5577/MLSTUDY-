# %%
import os
os.environ['OMP_NUM_THREADS']='4'

import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs#按照高斯分布生成数据集
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score,silhouette_score

# %%
x,y = make_blobs(n_samples=1000,n_features=2,centers=[[-1, -1], [0, 0], [1, 1], [2, 2]],cluster_std=[0.4, 0.2, 0.2, 0.2],random_state = 23)
plt.scatter(x[:, 0], x[:, 1], marker='o')
plt.show()

# %%
estimator = KMeans(n_clusters=4,random_state=23)
y_pred = estimator.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_pred)
print(calinski_harabasz_score(x,y_pred))
plt.show()
# Out:
# 6629.976987257438
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
sse_list = []
for clu_num in range(2,100):#考虑簇外 至少两个
    estimator1 = KMeans(n_clusters=clu_num,max_iter=100,random_state=23)
    y_pred = estimator1.fit_predict(x)
    value = silhouette_score(x,y_pred)#SC轮廓系数计算
    
    sse_list.append(value)
    
#print(sse_list)
plt.figure(figsize=(20,10))
plt.title('SSE value')
plt.xticks(range(0,100,3))
plt.xlabel('k')
plt.ylabel('sse')
plt.grid()#网格
plt.plot(range(2,100),sse_list)
plt.show()
# Out:
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# ...

# %%
sse_list = []
for clu_num in range(2,100):#考虑簇外 至少两个
    estimator1 = KMeans(n_clusters=clu_num,max_iter=100,random_state=23)
    y_pred = estimator1.fit_predict(x)
    value = calinski_harabasz_score(x,y_pred)#ch轮廓系数计算
    
    sse_list.append(value)
    
#print(sse_list)
plt.figure(figsize=(20,10))
plt.title('SSE value')
plt.xticks(range(0,100,3))
plt.xlabel('k')
plt.ylabel('sse')
plt.grid()#网格
plt.plot(range(2,100),sse_list)
plt.show()
# Out:
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Lenovo\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# ...
