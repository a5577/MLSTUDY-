# %%
#GBDT算法 泰坦尼克号生还预测

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier      # 回归决策树
#from sklearn.linear_model import LinearRegression   # 线性回归
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder#标签编码器
from sklearn.metrics import accuracy_score

# %%
#数据加载
data = pd.read_csv('./titanic_train.csv')
#data.info()
#数据预处理
#提取特征
x = data[['Pclass', 'Sex', 'Age']]
y = data['Survived']
#数据填充 age列有缺失 我们用该列的平均值进行填充
#数据复制 进行填充
x = x.copy()
x['Age'] = x['Age'].fillna(x['Age'].mean())
#x.info()
#将性别变成onehot
x = pd.get_dummies(x,columns=['Sex'])
x.info()
#划分数据集
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23)
#模型创建
#单个决策树
estimator1 = DecisionTreeClassifier()
estimator1.fit(x_train,y_train)
y_pred1 = estimator1.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print('-'*20)
#GBDT
estimator2 = GradientBoostingClassifier()
estimator2.fit(x_train,y_train)
y_pred2 = estimator2.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print('-'*20)
#网格搜素
params = {'n_estimators':[30,40,50,60,100,110],'learning_rate':[0.1,0.3,0.5],'max_depth':[4,5,6,8,10]}
estimator3 = GridSearchCV(estimator2,param_grid=params,cv = 3)
estimator3.fit(x_train,y_train)
y_pred3 = estimator3.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(estimator3.best_estimator_)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pclass      891 non-null    int64
#  1   Age         891 non-null    float64
#  2   Sex_female  891 non-null    bool
#  3   Sex_male    891 non-null    bool
# dtypes: bool(2), float64(1), int64(1)
# memory usage: 15.8 KB
# 0.8044692737430168
# --------------------
# 0.8100558659217877
# --------------------
# 0.7988826815642458
# GradientBoostingClassifier(max_depth=4, n_estimators=30)
